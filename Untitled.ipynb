# %%
import pandas as pd
from collections import Counter
import numpy as np
from lifelines import KaplanMeierFitter

df_ED = pd.read_csv('./Event_duration.csv')
df_PC = pd.read_csv('./Patient_characteristics.csv')

# %%
# %matplotlib inline

# %%
print ('Changeing string Yes/No to 0/1\n################\n')
df = pd.merge(df_ED,df_PC,how='inner')
display(df.groupby('treatment_variable').apply(len))
df['Target'] = df['treatment_variable']=='Drug_B'
del df['treatment_variable']
for i in ['other_drugs_1', 'other_drugs_2', 'other_drugs_3', 'other_drugs_4',
       'other_drugs_5', 'other_drugs_6', 'other_drugs_7', 'other_drugs_8',
       'diagnosis_1', 'diagnosis_2', 'diagnosis_3', 'diagnosis_4',
       'diagnosis_5', 'diagnosis_6', 'diagnosis_7', 'diagnosis_8',
       'diagnosis_9', 'diagnosis_10', 'diagnosis_11', 'diagnosis_12',
       'diagnosis_13', 'diagnosis_14', 'diagnosis_15']:
    print (Counter(df[i]))
    df[i] = df[i].map({0:0,1:1,'Yes':1,'No':0})
# Out:
# Changeing string Yes/No to 0/1
# ################
# treatment_variable
# Drug_A     8518
# Drug_B    10766
# dtype: int64
# Counter({'No': 14567, 'Yes': 4717})
# Counter({'No': 16438, 'Yes': 2846})
# Counter({'Yes': 10084, 'No': 9200})
# Counter({'No': 15707, 'Yes': 3577})
# Counter({'No': 18793, 'Yes': 491})
# Counter({'No': 16619, 'Yes': 2665})
# Counter({'No': 12578, 'Yes': 6706})
# Counter({'No': 14412, 'Yes': 4872})
# Counter({'Yes': 10424, 'No': 8860})
# Counter({'No': 15206, 'Yes': 4078})
# Counter({'No': 17920, 'Yes': 1364})
# Counter({'No': 19127, 'Yes': 157})
# Counter({'No': 17904, 'Yes': 1380})
# Counter({'No': 17558, 'Yes': 1726})
# Counter({'No': 16929, 'Yes': 2355})
# Counter({'No': 10059, 'Yes': 9225})
# Counter({'No': 12176, 'Yes': 7108})
# Counter({'No': 15443, 'Yes': 3841})
# Counter({'No': 18472, 'Yes': 812})
# Counter({'No': 18750, 'Yes': 534})
# Counter({'No': 14974, 'Yes': 4310})
# Counter({'No': 17844, 'Yes': 1440})
# Counter({'No': 19046, 'Yes': 238})

# %%
df.iloc[0]
# Out:
# patient_id                                       0
# Bleeding_event (1=event, 0=censored)             0
# duration_in_years                         0.019178
# sex                                              1
# age                                             86
# other_drugs_1                                    0
# other_drugs_2                                    0
# other_drugs_3                                    0
# other_drugs_4                                    0
# other_drugs_5                                    0
# other_drugs_6                                    0
# other_drugs_7                                    0
# other_drugs_8                                    1
# diagnosis_1                                      0
# diagnosis_2                                      0
# diagnosis_3                                      0
# diagnosis_4                                      0
# diagnosis_5                                      0
# diagnosis_6                                      0
# diagnosis_7                                      0
# diagnosis_8                                      1
# diagnosis_9                                      0
# diagnosis_10                                     1
# diagnosis_11                                     0
# diagnosis_12                                     0
# diagnosis_13                                     1
# diagnosis_14                                     0
# diagnosis_15                                     0
# lab_1                                     0.974967
# lab_2                                   358.572186
# lab_3                                          NaN
# lab_4                                          NaN
# lab_5                                      5.49857
# lab_6                                    17.060713
# lab_7                                     1.077035
# lab_8                                    67.781782
# Diag_Score_1                                     5
# Diag_Score_2                                     5
# Target                                       False
# Name: 0, dtype: object

# %% [markdown]
# # 2. checking if the treatment time is confounded with any other variables, with a decision tree classifier (random forest was tried but only limited increase in explanatory power), using ROC_AUC as an evaluation metric. We can see that treatmnet is not randomized, as it can be predicted with ~0.8ROCAUC
# ### Used tree model because nulls can be imputed with a dummy number, in this case -999

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.cluster import KMeans

clf = DecisionTreeClassifier(random_state=0,max_depth = 6,min_samples_leaf=15,
                             class_weight=None,criterion='gini')
#clf = RandomForestClassifier(random_state=0,max_depth = 6,min_samples_split=10,class_weight='balanced',
#                            max_samples=0.5)

var = ['sex', 'age', 'other_drugs_1', 'other_drugs_2',
       'other_drugs_3', 'other_drugs_4', 'other_drugs_5', 'other_drugs_6',
       'other_drugs_7', 'other_drugs_8', 'diagnosis_1', 'diagnosis_2',
       'diagnosis_3', 'diagnosis_4', 'diagnosis_5', 'diagnosis_6',
       'diagnosis_7', 'diagnosis_8', 'diagnosis_9', 'diagnosis_10',
       'diagnosis_11', 'diagnosis_12', 'diagnosis_13', 'diagnosis_14',
       'diagnosis_15', 'lab_1', 'lab_2', 'lab_3', 'lab_4', 'lab_5', 'lab_6',
       'lab_7', 'lab_8', 'Diag_Score_1', 'Diag_Score_2',]
#var = ['other_drugs_8','lab_1','lab_7']
def scorer(clf,X,y):
    preds = clf.predict_proba(X)[:,1]
    return roc_auc_score(y,preds)
    
score = cross_val_score(clf, df[var].fillna(-999), df['Target'], cv=10,scoring=scorer)
print('CV ROC-auc-score:', score)
print('average ROC-auc-score:', np.mean(score),np.std(score)/10**.5)
# Out:
# CV ROC-auc-score: [0.79530222 0.78831555 0.79280823 0.80913226 0.79154231 0.79511362
#  0.79879946 0.789034   0.77854062 0.79341798]
# average ROC-auc-score: 0.7932006251471531 0.0023501741855810232

# %%
print('Even the prescence of Nulls can explain the type of drug given at 0.65 AUC')

score = cross_val_score(clf, df[var].isnull(), df['Target'], cv=10,scoring=scorer)
print('CV ROC-auc-score:', score)
print('average ROC-auc-score:', np.mean(score),np.std(score)/10**.5)
# Out:
# Even the prescence of Nulls can explain the type of drug given at 0.65 AUC
# CV ROC-auc-score: [0.65464841 0.64722146 0.67498017 0.66183779 0.65883085 0.63647693
#  0.6548494  0.65905119 0.6317528  0.65467902]
# average ROC-auc-score: 0.6534328024521541 0.0037373522198436396

# %%
# this is just for demostrative purposes, this model not used
import sklearn
import matplotlib.pyplot as plt
clf = DecisionTreeClassifier(random_state=0,max_depth = 2,min_samples_leaf=30,
                             class_weight=None,criterion='entropy')
fig ,ax = plt.subplots(1,1,figsize=(50,20))
sklearn.tree.plot_tree(clf.fit(df[var].fillna(-999), df['Target']),
                        feature_names=var,fontsize=30)
# Out:
# [Text(1395.0, 906.0, 'lab_7 <= 1.331\nentropy = 0.99\nsamples = 19284\nvalue = [8518, 10766]'),
#  Text(697.5, 543.6, 'other_drugs_8 <= 0.5\nentropy = 0.982\nsamples = 13148\nvalue = [7624, 5524]'),
#  Text(348.75, 181.19999999999993, 'entropy = 0.937\nsamples = 9737\nvalue = [6295, 3442]'),
#  Text(1046.25, 181.19999999999993, 'entropy = 0.965\nsamples = 3411\nvalue = [1329, 2082]'),
#  Text(2092.5, 543.6, 'lab_7 <= 1.612\nentropy = 0.599\nsamples = 6136\nvalue = [894, 5242]'),
#  Text(1743.75, 181.19999999999993, 'entropy = 0.819\nsamples = 2214\nvalue = [565, 1649]'),
#  Text(2441.25, 181.19999999999993, 'entropy = 0.416\nsamples = 3922\nvalue = [329, 3593]')]

# %% [markdown]
# # 3. Since treatment is not at random, build a test set that is properly randomized as test set to see how method performs

# %%
#first find var the are potential confounders we should use for paired testing
impt_var = []
var2 = []
print ('Variables that are correlated with Treatment type')
for i in var:
    clf = DecisionTreeClassifier(random_state=0,max_depth = 3,min_samples_leaf=30,
                                 class_weight=None,criterion='entropy')

    def scorer(clf,X,y):
        preds = clf.predict_proba(X)[:,1]
        return roc_auc_score(y,preds)

    score = cross_val_score(clf, df[[i,]].fillna(df.mean()), df['Target'], cv=10,scoring=scorer)
    
    if np.mean(score) > 0.505:#+5*np.std(x): 
        print (i,np.mean(score))
        impt_var += [i]
        if np.mean(score)>0.555:
            var2 += [i,]
    if np.mean(df[i].isnull()) > 0:
        df[i+'_null'] = df[i].isnull()
        score = cross_val_score(clf, df[[i+'_null',]].fillna(df.mean()), df['Target'], cv=10,scoring=scorer)
        if np.mean(score) > 0.505:#+5*np.std(x): 
            print (i+'_null',np.mean(score))
            impt_var += [i+'_null']
            if np.mean(score)>0.555:
                var2 += [i+'_null',]
# Out:
# Variables that are correlated with Treatment type
# age 0.505441157426844
# other_drugs_1 0.5268677299165719
# other_drugs_2 0.5160982053792951
# other_drugs_3 0.5361909402979139
# other_drugs_7 0.511974785904006
# other_drugs_8 0.5647705814880402
# diagnosis_1 0.5110987846786554
# diagnosis_2 0.5113871442839611
# diagnosis_3 0.5065705076241482
# diagnosis_5 0.525173812903283
# diagnosis_6 0.5272725102346143
# diagnosis_7 0.5123799689206208
# diagnosis_8 0.5311010725779053
# diagnosis_9 0.5123348663156249
# diagnosis_10 0.5075293120925315
# diagnosis_13 0.5200019966775676
# lab_1 0.5626352416013493
# lab_2 0.5231619145316334
# lab_2_null 0.5128088948174327
# lab_3 0.5143389820477897
# lab_3_null 0.5143610618711548
# lab_4 0.5214116281579595
# lab_5 0.5561096024987584
# lab_5_null 0.5515137681530377
# lab_6 0.5552525955105722
# lab_7 0.7258224256160792
# lab_7_null 0.5599214549418039
# lab_8 0.5492515864198062
# lab_8_null 0.5536190319509241
# Diag_Score_1 0.5116365934600207
# Diag_Score_2 0.5079328324253081

# %% [markdown]
# ## Use PCA to dimension redcution followed by Kmeans to get 100 clusters, to get 100 groups for paired test

# %%
pca = sklearn.decomposition.PCA(whiten=True)
preds = pca.fit_transform(df.fillna(df.mean())[[x for x in impt_var ]])
#use first 3 PCs, 98.5% variance
print ('PCA explained variance',np.cumsum(pca.explained_variance_ratio_)[:5])
for i in range(3):
    df['PC%i'%i]=preds[:,i]
kmeans = KMeans(1000)
#othervar =  ['lab_1','lab_5','lab_8','other_drugs_8', 'lab_1', 'lab_7','diagnosis_8']
#use the 3 PCs + 3 most import var related to treatment type
X_kmeans = (df.fillna(df.mean())[['PC0','PC1','PC2']+var2]/df.fillna(df.mean())[['PC0','PC1','PC2']+var2].std())
#kmeans.fit(X_kmeans)
#df['Cluster']=kmeans.predict(X_kmeans).astype('str')
var = impt_var#['lab_5', 'lab_4', 'lab_1', 'other_drugs_8', 'lab_7']
clf_confounding = DecisionTreeClassifier(random_state=0,max_depth = 6,min_samples_leaf=15,
                             class_weight=None,criterion='entropy')
clf_confounding.fit(df[var].fillna(-999),df['Target'])
df['Cluster'] = clf_confounding.apply(df[var].fillna(-999))


df['index'] = df.index
d=df.groupby(['Cluster','Target']).apply(len).reset_index(drop=0)
d=pd.merge(d,df.groupby(['Cluster','Target'])['index'].apply(list).reset_index(drop=0))
d
# Out:
# PCA explained variance [0.58261281 0.95304124 0.97385606 0.98679958 0.99895023]
#     Cluster  Target     0                                              index
# 0         6   False  1790  [12, 29, 30, 34, 49, 50, 63, 78, 89, 106, 114,...
# 1         6    True  1132  [19, 25, 45, 65, 112, 113, 139, 164, 172, 211,...
# 2         7   False   540  [5, 14, 31, 79, 122, 134, 150, 160, 199, 251, ...
# 3         7    True   146  [196, 834, 846, 873, 1198, 1246, 1380, 1455, 1...
# 4         9   False  2696  [8, 9, 23, 26, 41, 48, 59, 68, 73, 75, 87, 88,...
# ..      ...     ...   ...                                                ...
# 76       84    True   591  [6, 52, 105, 124, 128, 255, 269, 383, 463, 466...
# 77       85   False     7    [3400, 6760, 12565, 13353, 15661, 15819, 18690]
# 78       85    True    19  [7, 205, 1087, 1109, 3740, 8667, 9530, 12145, ...
# 79       86   False    15  [1193, 1389, 2754, 6433, 6442, 8895, 9856, 102...
# 80       86    True     3                                  [219, 780, 13074]
#
# [81 rows x 4 columns]

# %%
import sklearn
import matplotlib.pyplot as plt
clf_confounding = DecisionTreeClassifier(random_state=0,max_depth = 6,min_samples_leaf=15,
                             class_weight=None,criterion='entropy')
clf_confounding.fit(df[var].fillna(-999),df['Target'])

fig ,ax = plt.subplots(1,1,figsize=(80,15))
sklearn.tree.plot_tree(clf_confounding,
                        feature_names=var,fontsize=13)
# Out:
# [Text(2711.88, 757.1571428571428, 'lab_7 <= 1.331\nentropy = 0.99\nsamples = 19284\nvalue = [8518, 10766]'),
#  Text(1584.72, 640.6714285714286, 'other_drugs_8 <= 0.5\nentropy = 0.982\nsamples = 13148\nvalue = [7624, 5524]'),
#  Text(833.2800000000001, 524.1857142857143, 'lab_1 <= 1.981\nentropy = 0.937\nsamples = 9737\nvalue = [6295, 3442]'),
#  Text(476.16, 407.7, 'lab_7 <= 1.138\nentropy = 0.921\nsamples = 9375\nvalue = [6224, 3151]'),
#  Text(238.08, 291.21428571428567, 'lab_5 <= 4.923\nentropy = 0.885\nsamples = 7246\nvalue = [5052, 2194]'),
#  Text(119.04, 174.7285714285714, 'lab_4 <= 5.404\nentropy = 0.938\nsamples = 3608\nvalue = [2330, 1278]'),
#  Text(59.52, 58.24285714285713, 'entropy = 0.963\nsamples = 2922\nvalue = [1790, 1132]'),
#  Text(178.56, 58.24285714285713, 'entropy = 0.747\nsamples = 686\nvalue = [540, 146]'),
#  Text(357.12, 174.7285714285714, 'lab_4 <= 4.75\nentropy = 0.814\nsamples = 3638\nvalue = [2722, 916]'),
#  Text(297.6, 58.24285714285713, 'entropy = 0.785\nsamples = 3519\nvalue = [2696, 823]'),
#  Text(416.64000000000004, 58.24285714285713, 'entropy = 0.757\nsamples = 119\nvalue = [26, 93]'),
#  Text(714.24, 291.21428571428567, 'lab_7 <= 1.273\nentropy = 0.993\nsamples = 2129\nvalue = [1172, 957]'),
#  Text(595.2, 174.7285714285714, 'lab_2 <= 228.014\nentropy = 0.982\nsamples = 1678\nvalue = [971, 707]'),
#  Text(535.6800000000001, 58.24285714285713, 'entropy = 0.955\nsamples = 1007\nvalue = [628, 379]'),
#  Text(654.72, 58.24285714285713, 'entropy = 1.0\nsamples = 671\nvalue = [343, 328]'),
#  Text(833.2800000000001, 174.7285714285714, 'lab_5 <= 7.441\nentropy = 0.991\nsamples = 451\nvalue = [201, 250]'),
#  Text(773.76, 58.24285714285713, 'entropy = 0.985\nsamples = 424\nvalue = [181, 243]'),
#  Text(892.8000000000001, 58.24285714285713, 'entropy = 0.826\nsamples = 27\nvalue = [20, 7]'),
#  Text(1190.4, 407.7, 'lab_1 <= 4.454\nentropy = 0.714\nsamples = 362\nvalue = [71, 291]'),
#  Text(1011.84, 291.21428571428567, 'lab_6 <= 10.602\nentropy = 0.839\nsamples = 257\nvalue = [69, 188]'),
#  Text(952.32, 174.7285714285714, 'entropy = 0.286\nsamples = 20\nvalue = [1, 19]'),
#  Text(1071.3600000000001, 174.7285714285714, 'lab_6 <= 27.755\nentropy = 0.865\nsamples = 237\nvalue = [68, 169]'),
#  Text(1011.84, 58.24285714285713, 'entropy = 0.887\nsamples = 220\nvalue = [67, 153]'),
#  Text(1130.88, 58.24285714285713, 'entropy = 0.323\nsamples = 17\nvalue = [1, 16]'),
#  Text(1368.96, 291.21428571428567, 'diagnosis_1 <= 0.5\nentropy = 0.136\nsamples = 105\nvalue = [2, 103]'),
#  Text(1309.44, 174.7285714285714, 'diagnosis_6 <= 0.5\nentropy = 0.25\nsamples = 48\nvalue = [2, 46]'),
#  Text(1249.92, 58.24285714285713, 'entropy = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(1368.96, 58.24285714285713, 'entropy = 0.485\nsamples = 19\nvalue = [2, 17]'),
#  Text(1428.48, 174.7285714285714, 'entropy = 0.0\nsamples = 57\nvalue = [0, 57]'),
#  Text(2336.1600000000003, 524.1857142857143, 'lab_1 <= 1.92\nentropy = 0.965\nsamples = 3411\nvalue = [1329, 2082]'),
#  Text(1904.64, 407.7, 'lab_5 <= 4.836\nentropy = 0.979\nsamples = 3149\nvalue = [1306, 1843]'),
#  Text(1666.5600000000002, 291.21428571428567, 'lab_4 <= 5.2\nentropy = 0.924\nsamples = 1306\nvalue = [443, 863]'),
#  Text(1547.52, 174.7285714285714, 'lab_1 <= 1.296\nentropy = 0.901\nsamples = 1124\nvalue = [356, 768]'),
#  Text(1488.0, 58.24285714285713, 'entropy = 0.918\nsamples = 1005\nvalue = [335, 670]'),
#  Text(1607.0400000000002, 58.24285714285713, 'entropy = 0.672\nsamples = 119\nvalue = [21, 98]'),
#  Text(1785.6000000000001, 174.7285714285714, 'lab_6 <= 14.677\nentropy = 0.999\nsamples = 182\nvalue = [87, 95]'),
#  Text(1726.0800000000002, 58.24285714285713, 'entropy = 0.797\nsamples = 29\nvalue = [7, 22]'),
#  Text(1845.1200000000001, 58.24285714285713, 'entropy = 0.998\nsamples = 153\nvalue = [80, 73]'),
#  Text(2142.7200000000003, 291.21428571428567, 'lab_4 <= -497.223\nentropy = 0.997\nsamples = 1843\nvalue = [863, 980]'),
#  Text(2023.68, 174.7285714285714, 'lab_1 <= 0.945\nentropy = 1.0\nsamples = 1680\nvalue = [850, 830]'),
#  Text(1964.16, 58.24285714285713, 'entropy = 0.99\nsamples = 1013\nvalue = [566, 447]'),
#  Text(2083.2000000000003, 58.24285714285713, 'entropy = 0.984\nsamples = 667\nvalue = [284, 383]'),
#  Text(2261.76, 174.7285714285714, 'lab_7 <= 1.1\nentropy = 0.401\nsamples = 163\nvalue = [13, 150]'),
#  Text(2202.2400000000002, 58.24285714285713, 'entropy = 0.54\nsamples = 105\nvalue = [13, 92]'),
#  Text(2321.28, 58.24285714285713, 'entropy = 0.0\nsamples = 58\nvalue = [0, 58]'),
#  Text(2767.6800000000003, 407.7, 'lab_1 <= 3.899\nentropy = 0.429\nsamples = 262\nvalue = [23, 239]'),
#  Text(2618.88, 291.21428571428567, 'diagnosis_6 <= 0.5\nentropy = 0.562\nsamples = 167\nvalue = [22, 145]'),
#  Text(2499.84, 174.7285714285714, 'diagnosis_10 <= 0.5\nentropy = 0.811\nsamples = 68\nvalue = [17, 51]'),
#  Text(2440.32, 58.24285714285713, 'entropy = 0.904\nsamples = 50\nvalue = [16, 34]'),
#  Text(2559.36, 58.24285714285713, 'entropy = 0.31\nsamples = 18\nvalue = [1, 17]'),
#  Text(2737.92, 174.7285714285714, 'Diag_Score_2 <= 3.5\nentropy = 0.289\nsamples = 99\nvalue = [5, 94]'),
#  Text(2678.4, 58.24285714285713, 'entropy = 0.571\nsamples = 37\nvalue = [5, 32]'),
#  Text(2797.44, 58.24285714285713, 'entropy = 0.0\nsamples = 62\nvalue = [0, 62]'),
#  Text(2916.48, 291.21428571428567, 'lab_7 <= 1.237\nentropy = 0.084\nsamples = 95\nvalue = [1, 94]'),
#  Text(2856.96, 174.7285714285714, 'entropy = 0.0\nsamples = 80\nvalue = [0, 80]'),
#  Text(2976.0, 174.7285714285714, 'entropy = 0.353\nsamples = 15\nvalue = [1, 14]'),
#  Text(3839.0400000000004, 640.6714285714286, 'lab_7 <= 1.612\nentropy = 0.599\nsamples = 6136\nvalue = [894, 5242]'),
#  Text(3481.92, 524.1857142857143, 'lab_1 <= 3.17\nentropy = 0.819\nsamples = 2214\nvalue = [565, 1649]'),
#  Text(3422.4, 407.7, 'lab_6 <= 39.124\nentropy = 0.834\nsamples = 2135\nvalue = [565, 1570]'),
#  Text(3214.0800000000004, 291.21428571428567, 'lab_5 <= 5.191\nentropy = 0.817\nsamples = 2083\nvalue = [529, 1554]'),
#  Text(3095.04, 174.7285714285714, 'lab_4 <= 5.473\nentropy = 0.722\nsamples = 1131\nvalue = [226, 905]'),
#  Text(3035.52, 58.24285714285713, 'entropy = 0.677\nsamples = 1013\nvalue = [181, 832]'),
#  Text(3154.56, 58.24285714285713, 'entropy = 0.959\nsamples = 118\nvalue = [45, 73]'),
#  Text(3333.1200000000003, 174.7285714285714, 'lab_4 <= -497.08\nentropy = 0.902\nsamples = 952\nvalue = [303, 649]'),
#  Text(3273.6000000000004, 58.24285714285713, 'entropy = 0.926\nsamples = 874\nvalue = [298, 576]'),
#  Text(3392.6400000000003, 58.24285714285713, 'entropy = 0.344\nsamples = 78\nvalue = [5, 73]'),
#  Text(3630.7200000000003, 291.21428571428567, 'lab_1 <= 0.965\nentropy = 0.89\nsamples = 52\nvalue = [36, 16]'),
#  Text(3571.2000000000003, 174.7285714285714, 'lab_7 <= 1.47\nentropy = 0.672\nsamples = 34\nvalue = [28, 6]'),
#  Text(3511.6800000000003, 58.24285714285713, 'entropy = 0.31\nsamples = 18\nvalue = [17, 1]'),
#  Text(3630.7200000000003, 58.24285714285713, 'entropy = 0.896\nsamples = 16\nvalue = [11, 5]'),
#  Text(3690.2400000000002, 174.7285714285714, 'entropy = 0.991\nsamples = 18\nvalue = [8, 10]'),
#  Text(3541.44, 407.7, 'entropy = 0.0\nsamples = 79\nvalue = [0, 79]'),
#  Text(4196.16, 524.1857142857143, 'lab_6 <= 74.566\nentropy = 0.416\nsamples = 3922\nvalue = [329, 3593]'),
#  Text(4136.64, 407.7, 'lab_7 <= 2.007\nentropy = 0.404\nsamples = 3904\nvalue = [314, 3590]'),
#  Text(3928.32, 291.21428571428567, 'lab_8 <= 30.158\nentropy = 0.505\nsamples = 1833\nvalue = [205, 1628]'),
#  Text(3809.28, 174.7285714285714, 'lab_6 <= 9.735\nentropy = 0.374\nsamples = 735\nvalue = [53, 682]'),
#  Text(3749.76, 58.24285714285713, 'entropy = 0.0\nsamples = 58\nvalue = [0, 58]'),
#  Text(3868.8, 58.24285714285713, 'entropy = 0.396\nsamples = 677\nvalue = [53, 624]'),
#  Text(4047.36, 174.7285714285714, 'lab_8 <= 41.033\nentropy = 0.58\nsamples = 1098\nvalue = [152, 946]'),
#  Text(3987.84, 58.24285714285713, 'entropy = 0.968\nsamples = 38\nvalue = [15, 23]'),
#  Text(4106.88, 58.24285714285713, 'entropy = 0.555\nsamples = 1060\nvalue = [137, 923]'),
#  Text(4344.96, 291.21428571428567, 'lab_4 <= 6.789\nentropy = 0.297\nsamples = 2071\nvalue = [109, 1962]'),
#  Text(4285.4400000000005, 174.7285714285714, 'lab_2 <= 114.156\nentropy = 0.286\nsamples = 2045\nvalue = [102, 1943]'),
#  Text(4225.92, 58.24285714285713, 'entropy = 0.235\nsamples = 1406\nvalue = [54, 1352]'),
#  Text(4344.96, 58.24285714285713, 'entropy = 0.385\nsamples = 639\nvalue = [48, 591]'),
#  Text(4404.4800000000005, 174.7285714285714, 'entropy = 0.84\nsamples = 26\nvalue = [7, 19]'),
#  Text(4255.68, 407.7, 'entropy = 0.65\nsamples = 18\nvalue = [15, 3]')]

# %%
#np.random.seed(33)

tests_subjects = []
for i in pd.unique(d['Cluster']):
    temp = d[d['Cluster']==i]
    if len(temp) ==2 :
        #get number of people as test set (10%)
        num_test = min(np.sum(temp[0])//2+1,temp[0].min())
        tests_subjects += [np.random.choice(temp.iloc[0]['index'],size=num_test,replace=False),]
        tests_subjects += [np.random.choice(temp.iloc[1]['index'],size=num_test,replace=False),]
  
tests_subjects = np.concatenate(tests_subjects)  
df['test'] = 0
df.loc[tests_subjects,'test'] = 1
df[df['test']==1][['Cluster','Target']].corr()
print('this is number of exmaples in test split per cluster')
display(df[df['test']==1].groupby(['Cluster','Target']).apply(len))
#double confirm target is not related to any mediation regime
print('This is correlation of varialbes with Target')
allvar = sorted(list(set(var+var2)))
display((100*np.abs(pd.get_dummies(df.fillna(df.mean())[df['test']==1][var+['Target',]]).corr()['Target'])).astype(np.int32))
print ('sucessfully chosen %s into test set, totally %s'%(len(tests_subjects),len(tests_subjects)/len(df)))
df_train  = df[df['test']==0]
df_test  = df[df['test']==1]
duration = 'duration_in_years'
event='Bleeding_event (1=event, 0=censored)'
ax = plt.subplot(111)
E = df_test[df_test['Target']==0][event]
T = df_test[df_test['Target']==0][duration]
kmf = KaplanMeierFitter()
kmf.fit(T, event_observed=E,label='TargetA')
ax = kmf.plot_survival_function(ax=ax)



E = df_test[df_test['Target']==1][event]
T = df_test[df_test['Target']==1][duration]


kmf.fit(T, event_observed=E,label='TargetB')
ax = kmf.plot_survival_function(ax=ax)
#plt.plot(cph.baseline_survival_,color='red')
df_train  = df[df['test']==0]
df_test  = df[df['test']==1]
duration = 'duration_in_years'
event='Bleeding_event (1=event, 0=censored)'


clf = DecisionTreeClassifier(random_state=0,max_depth = 7,min_samples_leaf=25,
                             class_weight=None,criterion='entropy')
#clf = RandomForestClassifier(random_state=0,max_depth = 6,min_samples_split=30,class_weight='balanced',
#                            max_samples=0.5)

var = ['sex', 'age', 'other_drugs_1', 'other_drugs_2',
       'other_drugs_3', 'other_drugs_4', 'other_drugs_5', 'other_drugs_6',
       'other_drugs_7', 'other_drugs_8', 'diagnosis_1', 'diagnosis_2',
       'diagnosis_3', 'diagnosis_4', 'diagnosis_5', 'diagnosis_6',
       'diagnosis_7', 'diagnosis_8', 'diagnosis_9', 'diagnosis_10',
       'diagnosis_11', 'diagnosis_12', 'diagnosis_13', 'diagnosis_14',
       'diagnosis_15', 'lab_1', 'lab_2', 'lab_3', 'lab_4', 'lab_5', 'lab_6',
       'lab_7', 'lab_8', 'Diag_Score_1', 'Diag_Score_2',]
def scorer(clf,X,y):
    preds = clf.predict_proba(X)[:,1]
    return roc_auc_score(y,preds)

score = cross_val_score(clf, df_test[var].fillna(-999), df_test['Target'], cv=10,scoring=scorer)
print('CV ROC-auc-score:', score)
print('average ROC-auc-score:', np.mean(score),np.std(score)/10**.5)
plt.show()
ax = plt.subplot(111)
plt.title('Test Set')
E = df_test[df_test['Target']==0][event]
T = df_test[df_test['Target']==0][duration]

kmf.fit_right_censoring(T, event_observed=E,label='TargetA')
ax = kmf.plot_survival_function(ax=ax)

ax = plt.subplot(111)
kmf = KaplanMeierFitter()
E = df_test[df_test['Target']==1][event]
T = df_test[df_test['Target']==1][duration]


kmf.fit(T, event_observed=E,label='TargetB')
ax = kmf.plot_survival_function(ax=ax)
#plt.plot(cph.baseline_survival_,color='red')

from lifelines.statistics import logrank_test
results = logrank_test(df_test[df_test['Target']==0][duration],  
                       df_test[df_test['Target']==1][duration], 
                       event_observed_A=df_test[df_test['Target']==0][event], 
                       event_observed_B=df_test[df_test['Target']==1][event])

results.print_summary()
print('pval:',results.p_value)        # 0.7676
print(results.test_statistic) # 0.0872
plt.title(' Balanced Test Set pval: '+str(np.round(results.p_value,3)))

plt.show()
# Out:
# this is number of exmaples in test split per cluster
# Cluster  Target
# 6        False     1132
#          True      1132
# 7        False      146
#          True       146
# 9        False      823
#                    ...
# 84       True        48
# 85       False        7
#          True         7
# 86       False        3
#          True         3
# Length: 74, dtype: int64
# This is correlation of varialbes with Target
# sex                1
# age                0
# other_drugs_1      5
# other_drugs_2      2
# other_drugs_3      2
# other_drugs_4      0
# other_drugs_5      0
# other_drugs_6      1
# other_drugs_7      4
# other_drugs_8      0
# diagnosis_1        0
# diagnosis_2        3
# diagnosis_3        4
# diagnosis_4        3
# diagnosis_5        5
# diagnosis_6        0
# diagnosis_7        5
# diagnosis_8        4
# diagnosis_9        4
# diagnosis_10       0
# diagnosis_11       3
# diagnosis_12       2
# diagnosis_13       1
# diagnosis_14       3
# diagnosis_15       0
# lab_1              2
# lab_2              2
# lab_3              0
# lab_4              1
# lab_5              3
# lab_6              6
# lab_7              2
# lab_8              2
# Diag_Score_1       0
# Diag_Score_2       0
# Target           100
# Name: Target, dtype: int32
# sucessfully chosen 10312 into test set, totally 0.5347438290811035
# CV ROC-auc-score: [0.5421568  0.55525509 0.55703695 0.57318432 0.56996688 0.54775532
#  0.5521713  0.55434824 0.54754271 0.50171973]
# average ROC-auc-score: 0.5501137335234125 0.005865486802012568
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.48 0.49      1.04
# pval: 0.48664749426184606
# 0.48393014644234134
# Text(0.5, 1.0, ' Balanced Test Set pval: 0.487')

# %%
from sklearn.metrics import normalized_mutual_info_score
def AOCROC_score2(a,b):
    clf = DecisionTreeClassifier(random_state=0,max_depth = 3,min_samples_leaf=30,
                                 class_weight=None,criterion='entropy')

    def scorer(clf,X,y):
        preds = clf.predict_proba(X)[:,1]
        return roc_auc_score(y,preds)

    score = cross_val_score(clf, pd.DataFrame(b).fillna(-9), a, cv=10,scoring=scorer)
    return np.mean(score)
# this is a normalized version of mutual information, which can be used for binned continous distirbutions
v = df_test[impt_var+['Target']].corr()['Target']
for i in v.index:
    v.loc[i] = .5
    try:
        b = df_test[i]
        v.loc[i] = AOCROC_score2(df_test['Target'],
                                            b)
    except : None
v2 = df[impt_var+['Target']].corr()['Target']
for i in v2.index:
    v2.loc[i] = -999
    try:
        b = df[i]
        v2.loc[i] = AOCROC_score2(df['Target'],
                                            b)
    except : None
del v['Target']
del v2['Target']
for i in v.index:
    if 'null' in i:
        del v[i]
        del v2[i] #not do for null variables

# %%
labels = v.index
df_balanced_means = v.values
df_means = v2.values

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(1,1,figsize=(8,5))
rects1 = ax.bar(x - width/2, df_balanced_means, width, label='Balanced Dataset')
rects2 = ax.bar(x + width/2, df_means, width, label='Entire Dataset')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('ROC AUC')
ax.set_title('Scores by group and gender')
ax.set_xticks(x, labels,rotation=90)
ax.legend()

#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)
plt.ylim([0.5,1])
fig.tight_layout()

plt.show()

# %%
from lifelines import KaplanMeierFitter

ax = plt.subplot(111)
kmf = KaplanMeierFitter()
plt.title('Test Set')
E = df_test[df_test['Target']==0][event]
T = df_test[df_test['Target']==0][duration]

kmf.fit_right_censoring(T, event_observed=E,label='TargetA')
ax = kmf.plot_survival_function(ax=ax)

ax = plt.subplot(111)
kmf = KaplanMeierFitter()
E = df_test[df_test['Target']==1][event]
T = df_test[df_test['Target']==1][duration]


kmf.fit(T, event_observed=E,label='TargetB')
ax = kmf.plot_survival_function(ax=ax)
#plt.plot(cph.baseline_survival_,color='red')

from lifelines.statistics import logrank_test
results = logrank_test(df_test[df_test['Target']==0][duration],  
                       df_test[df_test['Target']==1][duration], 
                       event_observed_A=df_test[df_test['Target']==0][event], 
                       event_observed_B=df_test[df_test['Target']==1][event])

results.print_summary()
print('pval:',results.p_value)        # 0.7676
print(results.test_statistic) # 0.0872
plt.title(' Balanced Test Set pval: '+str(np.round(results.p_value,3)))
plt.show()
# Out:
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.48 0.49      1.04
# pval: 0.48664749426184606
# 0.48393014644234134

# %% [markdown]
# # perform analysis for subpoluations (clusters)

# %%
#check for subpopoulations which may have good efficacy 

for cluster in pd.unique(df_test['Cluster']):
    a = df[(df['Target']==0) & (df['Cluster']==cluster)][duration]
    b = df[(df['Target']==1) & (df['Cluster']==cluster)][duration]
    c = df[(df['Target']==0) & (df['Cluster']==cluster)][event]
    d = df[(df['Target']==1) & (df['Cluster']==cluster)][event]
    from lifelines.statistics import logrank_test
    results = logrank_test(a,  
                           b, 
                           event_observed_A=c, 
                           event_observed_B=d)
    
    if results.p_value < 0.1:
        print('pval:',results.p_value,'Cluster: ', cluster)
        print (len(a),len(b))
        ax = plt.subplot(111)
        kmf.fit(a, event_observed=c,label='TargetA')
        ax = kmf.plot_survival_function(ax=ax)
        kmf.fit(b, event_observed=d,label='TargetB')
        ax = kmf.plot_survival_function(ax=ax)
        plt.show()
# Out:
# pval: 0.007106092936092056 Cluster:  61
# 181 832
# pval: 0.06833148495496034 Cluster:  83
# 54 1352
# pval: 0.06540372531521443 Cluster:  36
# 7 22
# pval: 0.01660119508550683 Cluster:  48
# 16 34
# pval: 0.008150971593502705 Cluster:  27
# 2 17
